# %%
import pymysql
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def my_db():
    global db
    db = pymysql.connect(host='192.168.0.102',
                         port=3306,
                         user='cnu',
                         passwd='cnu123',
                         db='ner_core_tagging',
                         charset='utf8')


def link_bio(result):
    global string
    try:
        for i in range(len(result)):
            if result[i][1] == 'B':
                string = string + " " + result[i][0]

            elif result[i][1] == 'I':

                if result[i + 1][1] == 'B':
                    string = string + result[i][0] + " "
                else:
                    string = string + result[i][0]
    except:
        pass


def show_wordcloud(string):
    global wordcloud
    wordcloud = WordCloud(font_path='font/H2GTRE.TTF', background_color='white').generate(string)
    plt.figure(figsize=(22, 22))  # 이미지 사이즈 지정
    plt.imshow(wordcloud, interpolation='lanczos')  # 이미지의 부드럽기 정도
    plt.axis('off')  # x y 축 숫자 제거
    plt.show()
    # plt.savefig()


def run(sql):
    my_db()
    global cursor, string
    try:
        with db.cursor() as cursor:

            cursor.execute(sql)
            result = cursor.fetchall()
            string = ""
            new_result=[[0]*2 for _ in range(len(result))]

            for i in range(len(result)):
                new_result[i][0]=result[i][1]
                new_result[i][1]=result[i][2]
            print(new_result)
            link_bio(new_result)

            # string= list(string.split(" "))
            # while "" in string:
            #    string.remove("")
            print(string)  # string 배열 완성

            show_wordcloud(string)
    finally:
        db.close()

# %%
trm = """
        select distinct(NEWS_SEQ),NER_CNTNTS, bio from ner_ner_info
        where USE_AT='y' and (bio='B' or bio='I') and NER_TYPE ='TRM'
        order by MORP_SEQ;     
        """

run(trm)
# Out:
# [['회색', 'B'], ['악성종양', 'B'], ['시각', 'B'], ['호흡기', 'B'], ['항바이러스제', 'B'], ['감염증', 'B'], ['콜센터', 'B'], ['감염병', 'B'], ['갈색', 'B'], ['감염', 'B'], ['모바일', 'B'], ['백신', 'B'], ['전', 'B'], ['혈액', 'B'], ['신규', 'B'], ['주요', 'B'], ['발열', 'B'], ['northern', 'B'], ['병원체', 'B'], ['콜센터', 'B'], ['치료제', 'B'], ['콜센터', 'B'], ['치료제', 'B'], ['사람', 'B'], ['기침', 'B'], ['말라리아', 'B'], ['앞', 'B'], ['전화', 'B'], ['정상세포', 'B'], ['비위', 'B'], ['첩보', 'B'], ['선거개입', 'B'], ['하명수사', 'B'], ['낙선', 'B'], ['공공병원', 'B'], ['금융거래', 'B'], ['북녘', 'B'], ['선거운동', 'B'], ['프로농구', 'B'], ['정규리그', 'I'], ['홈경기', 'I'], ['홈경기', 'B'], ['턴오버', 'B'], ['마이크', 'B'], ['앞', 'B'], ['딥페이크', 'B'], ['비상전력공급장', 'B'], ['치', 'I'], ['UPS', 'B'], ['D', 'B'], ['램', 'I'], ['남측', 'B'], ['SNS', 'B'], ['이메일', 'B'], ['온라인', 'B'], ['스마트폰', 'B'], ['메일', 'B'], ['동북', 'B'], ['전후', 'B'], ['메탈지그', 'B'], ['타이라바', 'B'], ['위', 'B'], ['벤치마킹', 'B'], ['SNS', 'B'], ['브로드웨이', 'B'], ['트위터', 'B'], ['ARS', 'B'], ['RDD', 'B'], ['비례할당무작위추출', 'B'], ['표본오차', 'B'], ['신뢰수준', 'B'], ['홈페이지', 'B'], ['가중값', 'B'], ['국정', 'B'], ['남북관계', 'B'], ['사회통합', 'B'], ['정당투표', 'B'], ['유튜브', 'B'], ['캡처', 'B'], ['e', 'B'], ['커머스', 'I'], ['전자상거래', 'B'], ['서비스', 'I'], ['우먼스', 'B'], ['저스트', 'I'], ['두', 'I'], ['캠페인', 'I'], ['유튜브', 'B'], ['소셜네트워크서비스', 'B'], ['SNS', 'B'], ['인스타그램', 'B'], ['혈중알코올농', 'B'], ['도', 'I'], ['스폿', 'B'], ['spot', 'I'], ['단속', 'B'], ['퇴직위로금', 'B'], ['단기계약직', 'B'], ['사회', 'B'], ['적', 'I'], ['책임', 'I'], ['CSR', 'B'], ['테스트배드', 'B'], ['전기자동차산업', 'B'], ['OEM', 'B'], ['KD', 'B'], ['ODM', 'B'], ['배터리', 'B'], ['모듈', 'I'], ['배터리팩', 'B'], ['얼라이언스', 'B'], ['탄소소재산업', 'B'], ['홀로그램', 'B'], ['산업', 'I'], ['농생명식품산업', 'B'], ['고용지표', 'B'], ['소비자', 'B'], ['심리지수', 'I'], ['삼락농정', 'B'], ['농생명산업', 'I'], ['융복합', 'B'], ['미래신산업', 'I'], ['대동맥', 'B'], ['농협', 'B'], ['홈페이지', 'I'], ['온라인', 'B'], ['앞', 'B'], ['왼쪽', 'B'], ['전면', 'B'], ['인터뷰', 'B'], ['상하', 'B'], ['유튜브', 'B'], ['전자발찌', 'B'], ['기자회견', 'B'], ['SNS', 'B'], ['폐렴', 'B'], ['호흡곤란', 'B'], ['폐', 'B'], ['염증', 'I'], ['고열', 'B'], ['사스', 'B'], ['유전자', 'B'], ['바이러스', 'B'], ['가습기', 'B'], ['살균제', 'B'], ['폐질환', 'B'], ['인공지능', 'B'], ['뒤', 'B'], ['TV', 'B'], ['시청률', 'B'], ['연료전지', 'B'], ['왼쪽', 'B'], ['프리킥', 'B'], ['햄스트링', 'B'], ['기자회견', 'B'], ['앞', 'B'], ['포지셔닝', 'B'], ['온라인', 'B'], ['프렌차이즈', 'B'], ['오프라인', 'B'], ['전자공시시스템', 'B'], ['DART', 'B'], ['코스피', 'B'], ['코스피지수', 'B'], ['유가증권시장', 'B'], ['코스닥지수', 'B'], ['코스닥시장', 'B'], ['코스닥', 'B'], ['산업평균지수', 'B'], ['나스닥', 'B'], ['지수', 'I'], ['틱톡', 'B'], ['알레르기', 'B'], ['비염', 'I'], ['재채기', 'B'], ['콧물', 'B'], ['가려움', 'B'], ['구충제', 'B'], ['알벤다졸', 'B'], ['인터넷', 'B'], ['커뮤니티', 'B'], ['비염', 'B'], ['암', 'B'], ['항암제', 'B'], ['지구', 'B'], ['인구', 'I'], ['감축', 'I'], ['프로젝트', 'I'], ['백신', 'B'], ['뉴미디어', 'B'], ['건망증', 'B'], ['북쪽', 'B'], ['측면', 'B'], ['e', 'B'], ['한민족사업', 'I'], ['반도체', 'B'], ['직업병', 'B'], ['앞', 'B'], ['뇌종양', 'B'], ['눈물', 'B'], ['사람', 'B'], ['백혈병', 'B'], ['자유투', 'B'], ['붉은색', 'B'], ['남동부', 'B'], ['앞', 'B'], ['네이버', 'B'], ['V', 'I'], ['라이브', 'I'], ['트위터', 'B'], ['좌우', 'B'], ['왼쪽', 'B'], ['페널티아크', 'B'], ['북쪽', 'B'], ['남쪽', 'B'], ['코스피', 'B'], ['코스닥지수', 'B'], ['TV', 'B'], ['교통안전환', 'B'], ['경', 'I'], ['개선', 'I'], ['사업', 'I'], ['폐렴', 'B'], ['사스', 'B'], ['SARS', 'B'], ['호흡기', 'B'], ['고열', 'B'], ['독감', 'B'], ['감기', 'B'], ['발열', 'B'], ['감염', 'I'], ['메르스', 'B'], ['MERS', 'B'], ['조', 'B'], ['류', 'I'], ['인플루엔자', 'I'], ['병원체', 'B'], ['사망', 'B'], ['사망', 'B'], ['모바일', 'B'], ['스마트폰', 'B'], ['전자결제', 'B'], ['전자화폐', 'B'], ['오디션', 'B'], ['하얗', 'B'], ['뒤', 'B'], ['감기', 'B'], ['명실상부', 'B'], ['아래', 'B'], ['신규', 'B'], ['5', 'B'], ['G', 'I'], ['ICT', 'B'], ['반도체', 'B'], ['네트워크', 'B'], ['인공지능', 'B'], ['바이오헬스', 'B'], ['신남방', 'B'], ['국가균형발전프로젝트', 'B'], ['앞', 'B'], ['데이터베이스', 'B'], ['프로젝트파이낸싱', 'B'], ['PF', 'B'], ['직접투자', 'B'], ['보석', 'B'], ['위치정보시스템', 'B'], ['GPS', 'B'], ['단말기', 'B'], ['웹사이트', 'B'], ['트위터', 'B'], ['앞', 'B'], ['휴대전화', 'B'], ['CCTV', 'B'], ['노트북', 'B'], ['분노', 'B'], ['복수', 'B'], ['라디오', 'B'], ['핑크빛', 'B'], ['도발', 'B'], ['남부', 'B'], ['북부', 'I'], ['동부', 'B'], ['Hub', 'B'], ['S', 'B'],  ...
#  회색 악성종양 시각 호흡기 항바이러스제 감염증 콜센터 감염병 갈색 감염 모바일 백신 전 혈액 신규 주요 발열 northern 병원체 콜센터 치료제 콜센터 치료제 사람 기침 말라리아 앞 전화 정상세포 비위 첩보 선거개입 하명수사 낙선 공공병원 금융거래 북녘 선거운동 프로농구정규리그홈경기  홈경기 턴오버 마이크 앞 딥페이크 비상전력공급장치  UPS D램  남측 SNS 이메일 온라인 스마트폰 메일 동북 전후 메탈지그 타이라바 위 벤치마킹 SNS 브로드웨이 트위터 ARS RDD 비례할당무작위추출 표본오차 신뢰수준 홈페이지 가중값 국정 남북관계 사회통합 정당투표 유튜브 캡처 e커머스  전자상거래서비스  우먼스저스트두캠페인  유튜브 소셜네트워크서비스 SNS 인스타그램 혈중알코올농도  스폿spot  단속 퇴직위로금 단기계약직 사회적책임  CSR 테스트배드 전기자동차산업 OEM KD ODM 배터리모듈  배터리팩 얼라이언스 탄소소재산업 홀로그램산업  농생명식품산업 고용지표 소비자심리지수  삼락농정농생명산업  융복합미래신산업  대동맥 농협홈페이지  온라인 앞 왼쪽 전면 인터뷰 상하 유
마트폰 염증 앞 커넥트비티에스  웹툰 SNS 인스타그램 치매명  RD사업  토너먼트 스마트홈협동로봇  한컴오피스 홈서비스 안팎 외상 중증외상  의료수가 경기선행지수 소비자물가 구매관리지수 경기선행지수 실물지표 국가균형발전프로젝트  insukohytncokr  북동쪽 카카오톡 socialytncokr  www 러시아쪽쪽  남북관계 남북통일 해외 e 메일메일  왼쪽 전화 좌 우 중증 전화 바이패스 단톡방 안식년 국책사업 중증외상  국민청원 문자메시지 문자 면죄부 혈세 78  후미 앞 폐렴 서쪽 치매극복선도도서관  노인일자리및사회활동지원사업사업  주정차질서계도  위 ljw714kyongbukcom  후명  hjryukyongbukcom  hjh kyongbuk com yangkyongbukcom  hjryukyongbukcom  yangkyongbukcom  HACCP sdkimkyongbukcom  잡코리아 내진보강공사 상부원  마스터플랜 배기가스 헤지펀드 사재기 이미지 온스 백색 디젤 휘발유 신에너지차  하이브리드 장신구의혹  청와대선거개입수사  앞 수면제 졸피뎀 서쪽 유튜브채널  폐렴 CZ6079  발열 감염증 앞뒤 호흡기 백신 항바 ...

# %%
evt = """
        select distinct(NEWS_SEQ),NER_CNTNTS, bio from ner_ner_info
        where USE_AT='y' and (bio='B' or bio='I') and NER_TYPE ='EVT'
        order by MORP_SEQ;
        """
run(evt)
# Out:
# [['3', 'B'], ['성지순례', 'B'], ['6', 'I'], ['통화스와프', 'B'], ['2', 'B'], ['참좋은재가센터', 'B'], ['5', 'B'], ['1', 'B'], ['지방선거', 'B'], ['사건', 'B'], ['경선', 'B'], ['총선', 'B'], ['총선', 'B'], ['대선', 'B'], ['연쇄살인사건', 'B'], ['실종', 'B'], ['사건', 'I'], ['사건', 'B'], ['총선', 'B'], ['연합훈련', 'B'], ['무역전쟁', 'B'], ['개막전', 'B'], ['글로벌', 'B'], ['금융위기', 'I'], ['무역분쟁', 'B'], ['총파업', 'B'], ['행정고시', 'B'], ['총선', 'B'], ['선거', 'B'], ['총선', 'B'], ['선거', 'B'], ['사건', 'B'], ['시민보고회', 'B'], ['공모', 'B'], ['4', 'B'], ['차산업혁명', 'I'], ['아태마스터스대회', 'B'], ['새만금', 'B'], ['잼버리', 'B'], ['총선', 'B'], ['2', 'B'], ['총선', 'B'], ['총선', 'B'], ['대선', 'B'], ['지방선거', 'B'], ['총선', 'B'], ['일제강점기', 'B'], ['동남아시안게임', 'B'], ['시무식', 'B'], ['그룹', 'B'], ['시무식', 'I'], ['신년사', 'B'], ['신년인사회', 'B'], ['5', 'B'], ['18', 'I'], ['민주화운동', 'I'], ['민족주의', 'B'], ['가습기살균', 'B'], ['제', 'I'], ['사건', 'I'], ['반유대주의', 'B'], ['총선', 'B'], ['2', 'B'], ['차대전', 'I'], ['2', 'I'], ['산업기술보호법', 'B'], ['상견례', 'B'], ['월드컵', 'B'], ['시상식', 'B'], ['4', 'B'], ['15', 'I'], ['총선', 'I'], ['장외투쟁', 'B'], ['정전사태', 'B'], ['전쟁', 'B'], ['4', 'B'], ['15', 'I'], ['총선', 'I