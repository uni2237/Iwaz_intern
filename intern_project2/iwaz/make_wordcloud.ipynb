# %%
import pymysql
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def my_db():
    global db
    db = pymysql.connect(host='192.168.0.102',
                         port=3306,
                         user='cnu',
                         passwd='cnu123',
                         db='ner_core_tagging',
                         charset='utf8')


def link_bio(result):
    global string
    try:
        for i in range(len(result)):
            if result[i][1] == 'B':
                string = string + " " + result[i][0]

            elif result[i][1] == 'I':

                if result[i + 1][1] == 'B':
                    string = string + result[i][0] + " "
                else:
                    string = string + result[i][0]
    except:
        pass


def show_wordcloud(string):
    global wordcloud
    wordcloud = WordCloud(font_path='font/H2GTRE.TTF', background_color='white').generate(string)
    plt.figure(figsize=(22, 22))  # 이미지 사이즈 지정
    plt.imshow(wordcloud, interpolation='lanczos')  # 이미지의 부드럽기 정도
    plt.axis('off')  # x y 축 숫자 제거
    plt.show()
    # plt.savefig()


def run(sql):
    my_db()
    global cursor, string
    try:
        with db.cursor() as cursor:

            cursor.execute(sql)
            result = cursor.fetchall()
            string = ""

            link_bio(result)

            # string= list(string.split(" "))
            # while "" in string:
            #    string.remove("")
            print(string)  # string 배열 완성

            show_wordcloud(string)
    finally:
        db.close()

# %%
trm = """
        select distinct NER_CNTNTS, bio 
        from ner_morp_info as A
        join ner_ner_info as B
        ON (A.MORP_CNTNTS = B.NER_CNTNTS) AND (A.SNTNC_SEQ = B.SNTNC_SEQ) AND (A.NEWS_SEQ = B.NEWS_SEQ) AND B.USE_AT = 'Y' AND (B.BIO = 'B' OR B.BIO = 'I') and B.NER_TYPE ='TRM'        
        """

run(trm)
# Out:
#  비위 첩보 선거개입 하명수사 낙선 공공병원 금융거래 북녘 선거운동 프로농구정규리그홈경기  홈경기 턴오버 마이크 앞 딥페이크 비상전력공급장치  UPS D램  남측 SNS 이메일 온라인 스마트폰 메일 동북 전후 메탈지그 타이라바 위 벤치마킹 브로드웨이 트위터 ARS RDD 비례할당무작위추출 표본오차 신뢰수준 홈페이지 가중값 국정 남북관계 사회통합 정당투표 유튜브 캡처 e커머스  전자상거래서비스  우먼스저스트두캠페인  소셜네트워크서비스 인스타그램 혈중알코올농도  스폿spot  단속 퇴직위로금 단기계약직 사회적책임  CSR 테스트배드 전기자동차산업 OEM KD ODM 배터리모듈  배터리팩 얼라이언스 탄소소재산업 홀로그램산업  농생명식품산업 고용지표 소비자심리지수  삼락농정농생명산업  융복합미래신산업  대동맥 농협홈페이지  왼쪽 전면 인터뷰 상하 전자발찌 기자회견 폐렴 호흡곤란 폐염증  고열 사스 유전자 바이러스 가습기 살균제 폐질환 인공지능 뒤 TV 시청률 연료전지 프리킥 햄스트링 포지셔닝 프렌차이즈 오프라인 전자공시시스템 DART 코스피 코스피지수 유가증권시장 코스닥지수 코스닥시장 코스닥 산업평균지수 나스닥지수  틱톡 알레르기비염  재채기 콧물 가려움 구충제 알벤다졸 암 비염 인터넷 커뮤니티 항암제 지구인구감축프로젝트  백신 뉴미디어 건망증 북쪽 측면한민족사업  반도체 직업병 뇌종양 눈물 사람 백혈병 자유투 붉은색 남동부 네이버V라이브  좌우 페널티아크 남쪽 교통안전환경개선사업  SARS 호흡기감염  독감 감기 발열 메르스 MERS 조류인플루엔자  병원체 사망 모바일 전자결제 전자화폐 오디션 하얗 아래 명실상부 신규 5G  ICT 네트워크 바이오헬스 신남방 국가균형발전프로젝트 데이터베이스 프로젝트파이낸싱 PF 직접투자 보석 위치정보시스템 GPS 단말기 웹사이트 휴대전화 CCTV 노트북 분노 복수 라디오 핑크빛 도발 남부북부  동부 Hub SA1  수직Hub  서비스 부품 무력 남 오른쪽 비디오영상  옆 공한증 스마트홈커넥티드기술  감염 인플루엔자 IVI 디스플
올농도  스폿spot  단속 퇴직위로금 단기계약직 사회적책임  CSR 테스트배드 전기자동차산업 OEM KD ODM 배터리모듈  배터리팩 얼라이언스 탄소소재산업 홀로그램산업  농생명식품산업 고용지표 소비자심리지수  삼락농정농생명산업  융복합미래신산업  대동맥 농협홈페이지  온라인 농협홈페이지  앞 왼쪽 왼쪽 전면 전면 인터뷰 인터뷰 인터뷰 인터뷰 상하 유튜브 전자발찌 기자회견 기자회견 SNS 폐렴 폐렴 호흡곤란 폐염증  고열 사스 유전자 사스 바이러스 가습기 살균제 폐질환 폐질환 고열 인공지능 뒤 TV 시청률 연료전지 연료전지 왼쪽 왼쪽 왼쪽 프리킥 햄스트링 기자회견 앞 포지셔닝 온라인 프렌차이즈 오프라인 전자공시시스템 DART 코스피 코스피지수 유가증권시장 코스피 코스피 코스닥지수 코스닥시장 코스닥 코스피지수 산업평균지수 나스닥지수  틱톡 알레르기비염  재채기 콧물 가려움 재채기 구충제 알벤다졸 암 비염 인터넷 커뮤니티 구충제 비염 암 알벤다졸 암 구충제 알벤다졸 항암제 비염 암 구충제 인터넷 인터넷 지구인구감축프로젝트  백신
# ...

# %%
evt = """
        select distinct NER_CNTNTS, bio from ner_ner_info
        where USE_AT='y' and (bio='B' or bio='I') and NER_TYPE ='TRM'
        order by MORP_SEQ;
        """

run(evt)
# Out:
#  전 악성종양 혈액 치료제 northern 시각 정상세포 비위 첩보 선거개입 하명수사 낙선 공공병원 금융거래 북녘 선거운동 프로농구정규리그홈경기  홈경기 턴오버 마이크 앞 딥페이크 비상전력공급장치  UPS D램  SNS 이메일 온라인 스마트폰 메일 동북 전후 메탈지그 타이라바 위 벤치마킹 브로드웨이 트위터 ARS RDD 비례할당무작위추출 표본오차 신뢰수준 홈페이지 가중값 국정 남북관계 사회통합 정당투표 유튜브 e커머스  전자상거래 우먼스저스트  소셜네트워크서비스 혈중알코올농 스폿spot  단속 퇴직위로금 단기계약직책임  CSR 테스트배드 전기자동차산업 OEM KD ODM 배터리모듈  배터리팩 얼라이언스 탄소소재산업 홀로그램산업  농생명식품산업 고용지표 소비자심리지수  삼락농정농생명산업  융복합미래신산업  대동맥 농협 왼쪽 인터뷰 상하 전자발찌 폐렴 호흡곤란 폐염증  고열 사스 바이러스 가습기 살균제 폐질환 인공지능 뒤 TV 시청률 연료전지 프리킥 햄스트링 포지셔닝 프렌차이즈 오프라인 전자공시시스템 DART 코스피지수 유가증권시장 코스닥시장 코스닥 틱톡 알레르기비염  재채기 가려움 구충제 알벤다졸 커뮤니티 비염 암 항암제 지구인구감축프로젝트  백신 뉴미디어 건망증 측면한민족사업  반도체 직업병 뇌종양 눈물 사람 백혈병 자유투 붉은색 남동부 네이버V라이브  좌우 페널티아크 북쪽 남쪽 교통안전환경개선사업  호흡기 감기감염  조류인플루엔자  병원체 사망 모바일 전자결제 전자화폐 오디션 하얗 명실상부 아래 신규 네트워크 바이오헬스 신남방 국가균형발전프로젝트 데이터베이스 프로젝트파이낸싱 PF 직접투자 보석 위치정보시스템 GPS 단말기 웹사이트 휴대전화 CCTV 노트북 분노 복수 라디오 핑크빛 도발 남부북부  동부 수직Hub홈페이지  서비스 부품 무력 남 오른쪽 비디오영상  옆 공한증 스마트홈커넥티드기술  감염 인플루엔자 IVI 전면 뒤쪽 디스플레이 내비게이션 차창내비게이션  T맵  온라인동영상서비스 OTT 디지털콕핏비서  빅스비 엑시노스오토9칩셋  카메라 TCU we
# ...
